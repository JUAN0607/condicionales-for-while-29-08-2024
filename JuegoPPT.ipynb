# %%
import math
import random

# %%
import random

def play():
    user = input(" ¿Qué vas a usar? 'piedra','papel','tijeras' ")
    computer = random.choice (['piedra', 'papel', 'tijeras'])
    
    if user == computer:
        return 'Es un Empate'
    
    if is_win(user, computer):
        return '¡Ganaste!'
    return '¡Perdiste!'

def is_win(player, opponent):
    if (player == 'piedra' and opponent == 'tijeras') or (player == 'tijeras' and opponent == 'papel') \
        or (player == 'papel' and opponent == 'tijeras'):
        return True
    
print(play())
# Out:
# ¡Perdiste!

# %%
for i in range(5):
        print(f"Ronda {i + 1}:")
        resultado = play()
        print(resultado)
        print()
# Out:
# Ronda 1:
# Es un Empate
#
# Ronda 2:
# ¡Perdiste!
#
# Ronda 3:
# ¡Ganaste!
#
# Ronda 4:
# ¡Perdiste!
#
# Ronda 5:

# %%
# !"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz

import random

chars = '!"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
password = ''

lengthPW = int (input('¿Que longitud quieres para tu pw?'))

for _ in range(lengthPW):

    password += random.choice(chars)
    
print(password)
# Out:
# gkVME+h%pEMxB?0C2KK

# %%
# !"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz

import random

random.seed(1234)

chars = '!"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
password = ''

lengthPW = int (input('¿Que longitud quieres para tu pw?'))

for _ in range(lengthPW):

    password += random.choice(chars)
    
print(password)
# Out:
# e0!-w%,.TE#$#Sjh5-90"mkF*rh*y-nw&It*MjTIF@gp#n+!Q4iW7(+xl6+tB4$S0p4Ng&bJ&8I5M5h&uXSlRwhi&iy7eoeLJ19bd1p/kWG?S/6wI5Pf+,YB(K%Cm-ONg*wG+c@.Y?gmEUAnb8wAM)Tq5lsiQ32(74r*P7!)-4B&dYPAWJqMcOv5q-HJaZuJp0WJBMxY(SeDk7WN!+jYMcj9Zj6KxVySA7ougi$h/$Ui*3xQSLMwQuLu?nJ+qzARnQPgI,pxws1FGV3$Y%&A5OoTdn*NHkwCSm,#wQuD6jl3q*4qF7mmYP2tuqyf&V*Va&z+OD@SoWxl($f,LcR4kE$TxVb8+#B@zs4m2G(yhUyVKYaVDK"OwI1ry%BqvxVq9PLUI8g7!raE?eI8TxapkyxjjneV/pZw2/ik.rt2GE+QYLoTZs?zihOep/rh,+@8zQ8WI@H$6Oz.&)HcPRNxdv7WY"LyyKOF5?fzebmRoIdYHvlOFK66a6%DvrTrAde$sZ**+FWkWEMnPoof*M$m944Wc8p3M.krQy3IdiJO7*eDeF*I5tJ4YB@to4BRa!oS?Cs##UeE"bclbQwoFxvukNix##Lu1fvFYbA&dY0a88+V7D*nW%2Im$Sn)Jo#&aj$K9Dkv)LFfg8H6bNo"LPyA9%Nzl#c6dRK.,vbuQpz%aep9Z/toQxoq?o.Y-On2+QjH+*zf"T%xB/fs8v&ImwZNw%vRrRB-oF.M#*,$MtSd#Yg-B,SQTXT.$23fT2.)Iu6%Rtly,mdU#bO?r7vDc7dl3WmivXNuJH4T2HNFL75zwg)HbV(S"m%@N?iXKOtXbIfo)zQG?O.ZUUcLXaKGz7guT@n9)Wugw2EWMVazGCPteO17tG8ZfHJf-7ogk()MBW2aw+?5LVL9wqdi(EvwjY.6z(0.421iV/t#,A3OWGcLUfD*O(AMZpVplNG79Oz#&RnQUg1d,Lbo/P3YIj&W!a$Cput*w*oVUk&)!#qCx1X

# %%
contraseña = "Juan060724."

contador = 0 

while True:
        contraseña_input = input("Introduzca una contraseña")
        contador +=1
        
        if contador > 3 :
            print("Haz sobrepasado los intentos")
            
        elif contraseña_input == "Juan060724.":
            print("Felicitaciones, contraseña correcta")
            break
        
        else:
            print("Contraseña incorrecta")
# Out:
# Contraseña incorrecta
# Contraseña incorrecta
# Haz sobrepasado los intentos
# Haz sobrepasado los intentos
